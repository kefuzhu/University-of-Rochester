# %% [markdown]
# # Lab 10: Hashing

# %% [markdown]
# ## <font color=DarkRed>Your Exercise: Rehashing using Quadratic Probing.</font>
#
# Implement quadratic probing as a rehash technique. Use the `HashTable` implementation provided in my class notes.

# %% [markdown]
# ## <font color=green>Your Solution</font>
#
# *Use a variety of code, Markdown (text) cells below to create your solution. Nice outputs would be timing results, and even plots. You will be graded not only on correctness, but the clarity of your code, descriptive text and other output. Keep it succinct!*

# %%
class HashTable:
    def __init__(self, size):
        self.size = size
        self.slots = [None] * self.size
        self.data = [None] * self.size

    def put(self, key, data):
        
        if data is None:
            raise ValuError("None cannot be stored in this HashTable")
            
        hashvalue = self.hashfunction(key)
        
        if self.slots[hashvalue] == None:
            self.data[hashvalue] = data
            self.slots[hashvalue] = key
        else:
            if self.slots[hashvalue] == key:
                self.data[hashtable] = data  # update/replace
            else:  # collision circumstance
                # Initialize hashtimes to 1
                hashtimes = 1
                nextslot = self.rehash(hashvalue,hashtimes)
                while (self.slots[nextslot] != None and
                       self.slots[nextslot] != key):               
                    # Increment the hashtimes by 1
                    hashtimes += 1
                    nextslot = self.rehash(nextslot,hashtimes)
                
                # We only get here if the while loop ends, meaning we have space
                # to add a value, or update an existing one
                self.slots[nextslot] = key  # updating or new data insertion
                self.data[nextslot] = data
  
    def get(self, key):
        startslot = self.hashfunction(key)
        data = None
        stop = False
        found = False
        position = startslot
        hashtimes = 1
        
        while (self.slots[position] != None and
               not found and
               not stop):
            
            if self.slots[position] == key:  # We've found it
                found = True
                data = self.data[position]
            else:
                position = self.rehash(position, hashtimes)
                # Increment hash times by 1
                hashtimes += 1
                if position == startslot:  # key is not in the dictionary/hashtable/map
                    stop = True
                    
        return data

    def hash(self, astring):
        _sum = 0
        for i, c in enumerate(astring, start=1):
            _sum = _sum + ord(c)*i    
        return _sum%self.size

    def hashfunction(self, key):
        if isinstance(key, int):
            h = self.hash(str(key))
        elif isinstance(key, str):
            h = self.hash(key)
        else:
            raise NotImplementedError("This data type isn't available for keys")

        return h  # Key must be an int

    # Perform quadratic probing for rehash
    def rehash(self, oldhash, hashtimes):
        # The value need to be add to the original hash value for quadratic probing
        prob = hashtimes **2
        # Print message to confirm the quadratic probing has been done
        print('Perform quadratic probing to rehash. Add {} to the original hash value'.format(prob))
        # Return the new hash value
        return (oldhash + prob) % self.size
    
    def __getitem__(self, key):
        if not (isinstance(key, str) or isinstance(key, int)):
            raise TypeError("Key must be a string or int")
            
        val = self.get(key)
        
        if not val:  # it's None
            raise KeyError
        
        return val
        
    def __setitem__(self, key, value):
        if not (isinstance(key, str) or isinstance(key, int)):
            raise TypeError("Key must be a string or int")
            
        self.put(key, value)
        
    def __len__(self):
        counter = 0
        
        for key in self.slots:
            if key != None:
                counter += 1
                
        return counter
    
    def __contains__(self, key):
        return True if self.get(key) is not None else False
    
    def __str__(self):
        d_str = "{"
        for k, v in zip(self.slots, self.data):
            if k is not None:
                d_str += f"{repr(k)}:{repr(v)}, "
        d_str = d_str[:-2] + "}"
        return d_str
    
    def __repr__(self):
        return self.__str__()

# %% [markdown]
# ## Testing
#
# Show me that collision resolution is happening in a quadratic fashion. Perhaps instrument the `rehash` function to print some useful output when rehashing, or show the state of the `self.slots` list before or after a collision occurs. I'll leave it up to you to demonstrate.

# %%
# Import library
import requests
import random
# Get a list of words from http://t2.hhg.to/ospd.txt
req = requests.get("http://t2.hhg.to/ospd.txt")
# Obtain a random sample of 1000 words
words = random.sample(req.text.split("\n"),1000)
# Check the size of the word list
print(len(words))
# Out:
# 1000

# %%
# Initialize a HashTable of size 2000
ht = HashTable(2000)
# For each word in wordlist, add it to the HashTable
for i, word in enumerate(words):
    print(f"Adding word #{i}: {word}")
    ht.put(word, "No definition available")
# Out:
# Adding word #0: spies
# Adding word #1: averting
# Adding word #2: aweless
# Adding word #3: ruboff
# Adding word #4: boras
# Adding word #5: hawks
# Adding word #6: laniard
# Adding word #7: soulful
# Adding word #8: creepier
# Adding word #9: tabbying
# Adding word #10: manitous
# Adding word #11: wiretap
# Adding word #12: strawed
# Adding word #13: zemindar
# Adding word #14: moodily
# Adding word #15: antisnob
# Adding word #16: ripper
# Adding word #17: farcies
# Adding word #18: shriven
# Adding word #19: inwrap
# Adding word #20: wyle
# Adding word #21: areolate
# Adding word #22: footers
# Adding word #23: forcedly
# Adding word #24: cayennes
# Adding word #25: bioscopy
# Adding word #26: staters
# Adding word #27: tawdrier
# Adding word #28: prosing
# Adding word #29: molar
# Adding word #30: ruddocks
# Adding word #31: lingo
# Adding word #32: heyday
# Adding word #33: urbanise
# Adding word #34: foveola
# Adding word #35: duopsony
# Adding word #36: hornwort
# Adding word #37: fatheads
# Adding word #38: bowpot
# Adding word #39: isagoge
# Adding word #40: skulkers
# Adding word #41: resister
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #42: murk
# Adding word #43: nankeens
# Adding word #44: author
# Adding word #45: assize
# Adding word #46: angst
# Adding word #47: barbecue
# Adding word #48: carcase
# Adding word #49: nark
# Adding word #50: rawin
# Adding word #51: ultimo
# Adding word #52: vibrants
# Adding word #53: flutes
# Adding word #54: pachisi
# Adding word #55: bravers
# Adding word #56: uniting
# Adding word #57: dustheap
# Adding word #58: biffed
# Adding word #59: peskily
# Adding word #60: samphire
# Adding word #61: calypsos
# Adding word #62: ptotic
# Adding word #63: feeblest
# Adding word #64: oralism
# Adding word #65: stymied
# Adding word #66: biters
# Adding word #67: ceboid
# Adding word #68: arcuate
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #69: tusks
# Adding word #70: solaces
# Adding word #71: salute
# Adding word #72: flaunt
# Adding word #73: brios
# Adding word #74: paellas
# Adding word #75: medlar
# Adding word #76: mavie
# Adding word #77: apologia
# Adding word #78: opuntias
# Adding word #79: cupules
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #80: pushier
# Adding word #81: sunlit
# Adding word #82: kobs
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #83: wytes
# Adding word #84: jarring
# Adding word #85: outplays
# Adding word #86: tungsten
# Adding word #87: diluvium
# Adding word #88: enlaces
# Adding word #89: uraris
# Adding word #90: unisexes
# Adding word #91: presence
# Adding word #92: jaggy
# Adding word #93: gerent
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #94: placates
# Adding word #95: hymned
# Adding word #96: lozenges
# Adding word #97: buttered
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #98: lucences
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #99: orbit
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #100: sonobuoy
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #101: drouth
# Adding word #102: bored
# Adding word #103: aerodyne
# Adding word #104: unguenta
# Adding word #105: silts
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #106: lehrs
# Adding word #107: shirring
# Adding word #108: currants
# Adding word #109: mun
# Adding word #110: gingal
# Adding word #111: groschen
# Adding word #112: suaver
# Adding word #113: lasagnas
# Adding word #114: alula
# Adding word #115: coniosis
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #116: weaves
# Adding word #117: mesial
# Adding word #118: pollened
# Adding word #119: parlayed
# Adding word #120: iridium
# Adding word #121: greedy
# Adding word #122: invoice
# Adding word #123: unhouse
# Adding word #124: retaping
# Adding word #125: babesias
# Adding word #126: bricky
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #127: hyenic
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #128: cowboy
# Adding word #129: quandang
# Adding word #130: limekiln
# Adding word #131: colluded
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #132: reverer
# Adding word #133: mislaid
# Adding word #134: preluded
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #135: oblately
# Adding word #136: stulls
# Adding word #137: yupon
# Adding word #138: forged
# Adding word #139: nonmetal
# Adding word #140: chirpily
# Adding word #141: equine
# Adding word #142: eyewater
# Adding word #143: sunland
# Adding word #144: maziness
# Adding word #145: evolved
# Adding word #146: reseize
# Adding word #147: recourse
# Adding word #148: orangish
# Adding word #149: primeros
# Adding word #150: toneme
# Adding word #151: cigar
# Adding word #152: churched
# Adding word #153: swastica
# Adding word #154: ingulf
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #155: cozenage
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #156: divorcer
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #157: pacs
# Adding word #158: nape
# Adding word #159: smears
# Adding word #160: fatherly
# Adding word #161: pome
# Adding word #162: resetter
# Adding word #163: babu
# Adding word #164: kempt
# Adding word #165: fubs
# Adding word #166: disclaim
# Adding word #167: retirer
# Adding word #168: mamba
# Adding word #169: blitzes
# Adding word #170: tongued
# Adding word #171: eluants
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #172: polar
# Adding word #173: compact
# Adding word #174: reemits
# Adding word #175: jumped
# Adding word #176: eluting
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #177: chaufer
# Adding word #178: neomorph
# Adding word #179: fades
# Adding word #180: glosseme
# Adding word #181: weeders
# Adding word #182: whigs
# Adding word #183: refound
# Adding word #184: flexor
# Adding word #185: unchewed
# Adding word #186: mopokes
# Adding word #187: fermi
# Adding word #188: ogrism
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #189: almighty
# Adding word #190: rubiest
# Adding word #191: irrupt
# Adding word #192: pliantly
# Adding word #193: caphs
# Adding word #194: farted
# Adding word #195: scoot
# Adding word #196: woollen
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #197: laconic
# Adding word #198: barbicel
# Adding word #199: unbraced
# Adding word #200: swilled
# Adding word #201: landau
# Adding word #202: ocellar
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #203: esoteric
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #204: enisled
# Adding word #205: monikers
# Adding word #206: tabors
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #207: unformed
# Adding word #208: carbora
# Adding word #209: plaguy
# Adding word #210: picritic
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #211: slap
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #212: fucuses
# Adding word #213: gigas
# Adding word #214: venues
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #215: barware
# Adding word #216: hoarser
# Adding word #217: geese
# Adding word #218: raxing
# Adding word #219: mil
# Adding word #220: disjunct
# Adding word #221: urbs
# Adding word #222: ratooner
# Adding word #223: lairdly
# Adding word #224: snugging
# Adding word #225: allegers
# Adding word #226: dewiest
# Adding word #227: grafters
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #228: seldomly
# Adding word #229: peaches
# Adding word #230: leeks
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #231: aureole
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #232: hoplites
# Adding word #233: zemstva
# Adding word #234: barbules
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #235: tractate
# Adding word #236: clambers
# Adding word #237: chrismal
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #238: rusts
# Adding word #239: stomach
# Adding word #240: diminish
# Adding word #241: armoire
# Adding word #242: leftish
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #243: lambdoid
# Adding word #244: downplay
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #245: used
# Adding word #246: elenchi
# Adding word #247: nuking
# Adding word #248: yearbook
# Adding word #249: tentlike
# Adding word #250: tenable
# Adding word #251: nubbly
# Adding word #252: elate
# Adding word #253: railbird
# Adding word #254: lawyered
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #255: sip
# Adding word #256: moirai
# Adding word #257: ridleys
# Adding word #258: ogle
# Adding word #259: chays
# Adding word #260: sub
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #261: whinge
# Adding word #262: encoring
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #263: adaption
# Adding word #264: phrensy
# Adding word #265: poodle
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #266: depermed
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #267: arousers
# Adding word #268: loan
# Adding word #269: gillie
# Adding word #270: manikins
# Adding word #271: podagra
# Adding word #272: keenly
# Adding word #273: cicorees
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #274: komondor
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #275: nonempty
# Adding word #276: hottest
# Adding word #277: silesia
# Adding word #278: strangle
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #279: milt
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #280: appoint
# Adding word #281: nave
# Adding word #282: mandrill
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #283: hachures
# Adding word #284: trawley
# Adding word #285: outcries
# Adding word #286: essays
# Adding word #287: minyan
# Adding word #288: assorter
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #289: grocers
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #290: autarkic
# Adding word #291: bowknots
# Adding word #292: bowpots
# Adding word #293: detest
# Adding word #294: qanats
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #295: atony
# Adding word #296: swooping
# Adding word #297: postteen
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #298: curable
# Adding word #299: elements
# Adding word #300: felloes
# Adding word #301: treen
# Adding word #302: debarred
# Adding word #303: skeletal
# Adding word #304: sheering
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #305: seabirds
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #306: relying
# Adding word #307: effaced
# Adding word #308: clonk
# Adding word #309: feign
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #310: jarrahs
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #311: derisive
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #312: suggest
# Adding word #313: mazer
# Adding word #314: gramas
# Adding word #315: sook
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #316: fielded
# Adding word #317: fonder
# Adding word #318: nobbling
# Adding word #319: hyla
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #320: wergilds
# Adding word #321: hares
# Adding word #322: basilar
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #323: aggro
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #324: floodlit
# Adding word #325: woos
# Adding word #326: bruxism
# Adding word #327: unhooks
# Adding word #328: uphove
# Adding word #329: chiasm
# Adding word #330: rushier
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Adding word #331: dune
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #332: erectors
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #333: backbend
# Adding word #334: subvene
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #335: stodgier
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #336: endue
# Adding word #337: keirs
# Adding word #338: chiasmus
# Adding word #339: oxidants
# Adding word #340: saltiest
# Adding word #341: gassed
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #342: minders
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Adding word #343: epoch
# Adding word #344: niello
# Adding word #345: jowars
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #346: acapnia
# Adding word #347: another
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Adding word #348: sepia
# Adding word #349: spooneys
# Adding word #350: faddist
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #351: snottily
# Adding word #352: undreamt
# Adding word #353: moralist
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #354: pretext
# Adding word #355: invokers
# Adding word #356: reeked
# Adding word #357: veals
# Adding word #358: slushed
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #359: pas
# Adding word #360: toquets
# Adding word #361: donor
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #362: neuter
# Adding word #363: dysuria
# Adding word #364: frondeur
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #365: busings
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Adding word #366: drongo
# Adding word #367: generate
# Adding word #368: yodh
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #369: thorps
# Adding word #370: oystered
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #371: trameled
# Adding word #372: uranic
# Adding word #373: stuntman
# Adding word #374: nosher
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #375: larch
# Adding word #376: wishless
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #377: method
# Adding word #378: pratique
# Adding word #379: cardcase
# Adding word #380: movie
# Adding word #381: gammadia
# Adding word #382: forgot
# Adding word #383: naggier
# Adding word #384: staggy
# Adding word #385: emboss
# Adding word #386: tulles
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #387: rudesby
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #388: burd
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #389: deticker
# Adding word #390: captive
# Adding word #391: misheard
# Adding word #392: etherish
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #393: morion
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Adding word #394: isoprene
# Adding word #395: rickshas
# Adding word #396: journal
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #397: leporine
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #398: leaper
# Adding word #399: seconded
# Adding word #400: spatular
# Adding word #401: sienite
# Adding word #402: uncut
# Adding word #403: anting
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #404: pocked
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #405: pawning
# Adding word #406: anticks
# Adding word #407: albedo
# Adding word #408: remora
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #409: exiles
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #410: justs
# Adding word #411: oxygen
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #412: huskiest
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #413: toothy
# Adding word #414: chips
# Adding word #415: chamois
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #416: kingpins
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Adding word #417: vairs
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #418: likelier
# Adding word #419: narcose
# Adding word #420: dasyure
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Adding word #421: bartends
# Adding word #422: fruits
# Adding word #423: unitive
# Adding word #424: befouls
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #425: daedal
# Adding word #426: leaner
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #427: tiring
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #428: schnoz
# Adding word #429: entrain
# Adding word #430: beagle
# Adding word #431: atomist
# Adding word #432: gingalls
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #433: inerts
# Adding word #434: tame
# Adding word #435: notum
# Adding word #436: zebras
# Adding word #437: polestar
# Adding word #438: vanillin
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #439: rhesus
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #440: pack
# Adding word #441: swiddens
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Adding word #442: gear
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #443: floatel
# Adding word #444: ferrites
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #445: ahchoo
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #446: the
# Adding word #447: canape
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #448: thiazine
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Adding word #449: hootier
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #450: fugged
# Adding word #451: faucet
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #452: goodness
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Adding word #453: heels
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #454: retiming
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Adding word #455: remap
# Adding word #456: robbery
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #457: scrotum
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #458: miniski
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #459: brood
# Adding word #460: duelists
# Adding word #461: scenting
# Adding word #462: valencia
# Adding word #463: manikin
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #464: birse
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Adding word #465: bezoars
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #466: sill
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #467: silty
# Adding word #468: crispest
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #469: welkin
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #470: updating
# Adding word #471: or
# Adding word #472: amniote
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Adding word #473: venison
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Adding word #474: berimes
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #475: koshered
# Adding word #476: crucks
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #477: sparsity
# Adding word #478: swinking
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Adding word #479: curets
# Adding word #480: corers
# Adding word #481: joiner
# Adding word #482: quired
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #483: vogues
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #484: crabby
# Adding word #485: suffuses
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #486: nonrural
# Adding word #487: same
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Adding word #488: nictates
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #489: berouged
# Adding word #490: gangster
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Adding word #491: quizzers
# Adding word #492: shogged
# Adding word #493: topazes
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Adding word #494: cyclone
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #495: resemble
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #496: cools
# Adding word #497: tagged
# Adding word #498: lauwine
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Adding word #499: birk
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Adding word #500: sadden
# Adding word #501: solvers
# Adding word #502: paphians
# Adding word #503: sooners
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #504: sunroofs
# Adding word #505: cays
# Adding word #506: conceded
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Adding word #507: wifedoms
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #508: wedelns
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Adding word #509: defrost
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #510: mauve
# Adding word #511: darkeys
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #512: vizors
# Adding word #513: bye
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #514: surcease
# Adding word #515: tissual
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Adding word #516: nonplay
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #517: antiriot
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #518: cookless
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #519: gourmets
# Adding word #520: grudged
# Adding word #521: bowses
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #522: junkmen
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #523: viricide
# Adding word #524: hire
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Adding word #525: besmudge
# Adding word #526: stimying
# Adding word #527: unlaced
# Adding word #528: cerite
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #529: cultural
# Adding word #530: captans
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Adding word #531: seisors
# Adding word #532: hexapla
# Adding word #533: jacals
# Adding word #534: squeak
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #535: stotinki
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #536: walkups
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #537: brickbat
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #538: arising
# Adding word #539: meek
# Adding word #540: unforgot
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #541: hind
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #542: playwear
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #543: monetize
# Adding word #544: spahee
# Adding word #545: lipin
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #546: forayer
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #547: slabs
# Adding word #548: tassels
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Adding word #549: fritt
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #550: stumming
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Adding word #551: upshift
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Adding word #552: hagged
# Adding word #553: dahlia
# Adding word #554: transom
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Adding word #555: coaler
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #556: blow
# Adding word #557: blanking
# Adding word #558: outkicks
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #559: ghosts
# Adding word #560: eviler
# Adding word #561: enwinds
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Adding word #562: pillion
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Adding word #563: tragi
# Adding word #564: somites
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Adding word #565: stone
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #566: beanbags
# Adding word #567: tourisms
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #568: champy
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #569: yowl
# Adding word #570: undergod
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #571: plats
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #572: espanol
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #573: snapper
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Adding word #574: quaichs
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #575: cachexic
# Adding word #576: seedlike
# Adding word #577: rubbers
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Adding word #578: shelf
# Adding word #579: uncoined
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #580: retrofit
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Adding word #581: labella
# Adding word #582: replots
# Adding word #583: atomical
# Adding word #584: haplont
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Adding word #585: groggery
# Adding word #586: hogshead
# Adding word #587: revision
# Adding word #588: teacher
# Adding word #589: acre
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #590: defogger
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #591: cracky
# Adding word #592: immenser
# Adding word #593: auspex
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #594: panaceas
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #595: finale
# Adding word #596: clubable
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #597: plack
# Adding word #598: radiates
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Adding word #599: paiking
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #600: enwheel
# Adding word #601: wale
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Adding word #602: madding
# Adding word #603: detassel
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Adding word #604: malars
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #605: coolth
# Adding word #606: crescent
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# ...
# Adding word #954: scowder
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Perform quadratic probing to rehash. Add 81 to the original hash value
# Perform quadratic probing to rehash. Add 100 to the original hash value
# Adding word #955: enlarged
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #956: tint
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Adding word #957: rechewed
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Perform quadratic probing to rehash. Add 81 to the original hash value
# Perform quadratic probing to rehash. Add 100 to the original hash value
# Adding word #958: peepshow
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Adding word #959: holmiums
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Adding word #960: pantry
# Adding word #961: eme
# Adding word #962: lardiest
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Adding word #963: stalks
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Adding word #964: dizzier
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Adding word #965: licenced
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #966: wha
# Adding word #967: whiffled
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #968: creamily
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Perform quadratic probing to rehash. Add 81 to the original hash value
# Adding word #969: pushball
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #970: celiac
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #971: mobbish
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Perform quadratic probing to rehash. Add 81 to the original hash value
# Perform quadratic probing to rehash. Add 100 to the original hash value
# Adding word #972: dunnest
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Adding word #973: weepers
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Perform quadratic probing to rehash. Add 81 to the original hash value
# Adding word #974: terais
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Adding word #975: neutrino
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #976: mesocarp
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #977: cigaret
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #978: gobbled
# Adding word #979: ranches
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #980: thous
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #981: mimosa
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Perform quadratic probing to rehash. Add 81 to the original hash value
# Adding word #982: outgross
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #983: regear
# Adding word #984: mutate
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Adding word #985: misbegin
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Perform quadratic probing to rehash. Add 81 to the original hash value
# Perform quadratic probing to rehash. Add 100 to the original hash value
# Perform quadratic probing to rehash. Add 121 to the original hash value
# Perform quadratic probing to rehash. Add 144 to the original hash value
# Adding word #986: valves
# Adding word #987: hollands
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Adding word #988: sokemen
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Adding word #989: trochaic
# Adding word #990: gypsum
# Adding word #991: duumviri
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Adding word #992: barhops
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Adding word #993: hiccups
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Adding word #994: harslets
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Adding word #995: unevaded
# Adding word #996: pigboats
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Adding word #997: cruppers
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Adding word #998: ingress
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Adding word #999: thataway
# Perform quadratic probing to rehash. Add 1 to the original hash value
# Perform quadratic probing to rehash. Add 4 to the original hash value
# Perform quadratic probing to rehash. Add 9 to the original hash value
# Perform quadratic probing to rehash. Add 16 to the original hash value
# Perform quadratic probing to rehash. Add 25 to the original hash value
# Perform quadratic probing to rehash. Add 36 to the original hash value
# Perform quadratic probing to rehash. Add 49 to the original hash value
# Perform quadratic probing to rehash. Add 64 to the original hash value
# Perform quadratic probing to rehash. Add 81 to the original hash value
