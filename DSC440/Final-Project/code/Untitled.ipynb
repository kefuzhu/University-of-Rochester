# %%
import requests
import pandas as pd
from dateutil import parser, rrule
from datetime import datetime, time, date
import time

# %%
def getRainfallData(station, day, month, year):
    """
    Function to return a data frame of minute-level weather data for a single Wunderground PWS station.
    
    Args:
        station (string): Station code from the Wunderground website
        day (int): Day of month for which data is requested
        month (int): Month for which data is requested
        year (int): Year for which data is requested
    
    Returns:
        Pandas Dataframe with weather data for specified station and date.
    """
    url = "http://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID={station}&day={day}&month={month}&year={year}&graphspan=day&format=1"
    full_url = url.format(station=station, day=day, month=month, year=year)
    # Request data from wunderground data
    response = requests.get(full_url, headers={'User-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})
    data = response.text
    # remove the excess <br> from the text data
    data = data.replace('<br>', '')
    # Convert to pandas dataframe (fails if issues with weather station)
    try:
        dataframe = pd.read_csv(io.StringIO(data), index_col=False)
        dataframe['station'] = station
    except Exception as e:
        print("Issue with date: {}-{}-{} for station {}".format(day,month,year, station))
        return None
    return dataframe

# %%
# Generate a list of all of the dates we want data for
start_date = "2018-01-01"
end_date = "2018-12-31"
start = parser.parse(start_date)
end = parser.parse(end_date)
dates = list(rrule.rrule(rrule.DAILY, dtstart=start, until=end))

# Create a list of stations here to download data for
# - Greenwich Village: KNYNEWYO754
# - Morningside Heights: KNYNEWYO1207
# - Inwood: KNYNEWYO864
# - Allerton: KNYTHEBR2
# - 
stations = ["KNYNEWYO754", "KNYNEWYO1207", "KNYNEWYO864", "KNYTHEBR2"]
# Set a backoff time in seconds if a request fails
backoff_time = 10
data = {}

# Gather data for each station in turn and save to CSV.
for station in stations:
    print("Working on {}".format(station))
    data[station] = []
    for date in dates:
        # Print period status update messages
        if date.day % 10 == 0:
            print("Working on date: {} for station {}".format(date, station))
        done = False
        while done == False:
            try:
                weather_data = getRainfallData(station, date.day, date.month, date.year)
                done = True
            except ConnectionError as e:
                # May get rate limited by Wunderground.com, backoff if so.
                print("Got connection error on {}".format(date))
                print("Will retry in {} seconds".format(backoff_time))
                time.sleep(10)
        # Add each processed date to the overall data
        data[station].append(weather_data)
    # Finally combine all of the individual days and output to CSV for analysis.
    pd.concat(data[station]).to_csv("data/{}_weather.csv".format(station))
# Out:
# Working on KNYNEWYO754
# Issue with date: 1-1-2018 for station KNYNEWYO754
# Issue with date: 2-1-2018 for station KNYNEWYO754
# Issue with date: 3-1-2018 for station KNYNEWYO754
# Issue with date: 4-1-2018 for station KNYNEWYO754
# Issue with date: 5-1-2018 for station KNYNEWYO754
# Issue with date: 6-1-2018 for station KNYNEWYO754
# Issue with date: 7-1-2018 for station KNYNEWYO754
# Issue with date: 8-1-2018 for station KNYNEWYO754
# Issue with date: 9-1-2018 for station KNYNEWYO754
# Working on date: 2018-01-10 00:00:00 for station KNYNEWYO754
# Issue with date: 10-1-2018 for station KNYNEWYO754
# Issue with date: 11-1-2018 for station KNYNEWYO754
# Issue with date: 12-1-2018 for station KNYNEWYO754
# Issue with date: 13-1-2018 for station KNYNEWYO754
# Issue with date: 14-1-2018 for station KNYNEWYO754
# Issue with date: 15-1-2018 for station KNYNEWYO754
# Issue with date: 16-1-2018 for station KNYNEWYO754
# Issue with date: 17-1-2018 for station KNYNEWYO754
# Issue with date: 18-1-2018 for station KNYNEWYO754
# Issue with date: 19-1-2018 for station KNYNEWYO754
# Working on date: 2018-01-20 00:00:00 for station KNYNEWYO754
# Issue with date: 20
10 00:00:00 for station KNYNEWYO754
# Issue with date: 10-11-2018 for station KNYNEWYO754
# Issue with date: 11-11-2018 for station KNYNEWYO754
# Issue with date: 12-11-2018 for station KNYNEWYO754
# Issue with date: 13-11-2018 for station KNYNEWYO754
# Issue with date: 14-11-2018 for station KNYNEWYO754
# Issue with date: 15-11-2018 for station KNYNEWYO754
# Issue with date: 16-11-2018 for station KNYNEWYO754
# Issue with date: 17-11-2018 for station KNYNEWYO754
# Issue with date: 18-11-2018 for station KNYNEWYO754
# Issue with date: 19-11-2018 for station KNYNEWYO754
# Working on date: 2018-11-20 00:00:00 for station KNYNEWYO754
# Issue with date: 20-11-2018 for station KNYNEWYO754
# Issue with date: 21-11-2018 for station KNYNEWYO754
# Issue with date: 22-11-2018 for station KNYNEWYO754
# Issue with date: 23-11-2018 for station KNYNEWYO754
# Issue with date: 24-11-2018 for station KNYNEWYO754
# Issue with date: 25-11-2018 for station KNYNEWYO754
# Issue with date: 26-11-2018 for station KNYNEWYO754
# Issue with date: 27-11-2018 for station KNYNEWYO754
# Issue with date: 28-11-2018 for station KNYNEWYO754
# Issue with date: 29-11-2018 for station KNYNEWYO754
# Working on date: 2018-11-30 00:00:00 for station KNYNEWYO754
# Issue with date: 30-11-2018 for station KNYNEWYO754
# Issue with date: 1-12-2018 for station KNYNEWYO754
# Issue with date: 2-12-2018 for station KNYNEWYO754
# Issue with date: 3-12-2018 for station KNYNEWYO754
# Issue with date: 4-12-2018 for station KNYNEWYO754
# Issue with date: 5-12-2018 for station KNYNEWYO754
# Issue with date: 6-12-2018 for station KNYNEWYO754
# Issue with date: 7-12-2018 for station KNYNEWYO754
# Issue with date: 8-12-2018 for station KNYNEWYO754
# Issue with date: 9-12-2018 for station KNYNEWYO754
# Working on date: 2018-12-10 00:00:00 for station KNYNEWYO754
# Issue with date: 10-12-2018 for station KNYNEWYO754
# Issue with date: 11-12-2018 for station KNYNEWYO754
# Issue with date: 12-12-2018 for station KNYNEWYO754
# Issue with date: 13-12-2018 for station KNYNEWYO754
# Issue with date: 14-12-2018 for station KNYNEWYO754
# Issue with date: 15-12-2018 for station KNYNEWYO754
# Issue with date: 16-12-2018 for station KNYNEWYO754
# Issue with date: 17-12-2018 for station KNYNEWYO754
# Issue with date: 18-12-2018 for station KNYNEWYO754
# Issue with date: 19-12-2018 for station KNYNEWYO754
# Working on date: 2018-12-20 00:00:00 for station KNYNEWYO754
# Issue with date: 20-12-2018 for station KNYNEWYO754
# Issue with date: 21-12-2018 for station KNYNEWYO754
# Issue with date: 22-12-2018 for station KNYNEWYO754
# Issue with date: 23-12-2018 for station KNYNEWYO754
# Issue with date: 24-12-2018 for station KNYNEWYO754
# Issue with date: 25-12-2018 for station KNYNEWYO754
# Issue with date: 26-12-2018 for station KNYNEWYO754
# Issue with date: 27-12-2018 for station KNYNEWYO754
# Issue with date: 28-12-2018 for station KNYNEWYO754
# Issue with date: 29-12-2018 for station KNYNEWYO754
# Working on date: 2018-12-30 00:00:00 for station KNYNEWYO754
# Issue with date: 30-12-2018 for station KNYNEWYO754
# Issue with date: 31-12-2018 for station KNYNEWYO754
# --------------------------------------------------------
# ValueError             Traceback (most recent call last)
# <ipython-input-8-0f685c2dec9b> in <module>()
#      38         data[station].append(weather_data)
#      39     # Finally combine all of the individual days and output to CSV for analysis.
# ---> 40     pd.concat(data[station]).to_csv("data/{}_weather.csv".format(station))
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     275
#     276         if len(objs) == 0:
# --> 277             raise ValueError('All objects passed were None')
#     278
#     279         # consolidate data & figure out what our result ndim is going to be
#
# ValueError: All objects passed were None
